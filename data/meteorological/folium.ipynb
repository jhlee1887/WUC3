# %%
# !pip install charset
# !pip install charset-normalizer
# Out:
# Collecting charset
#   Downloading charset-1.0.1.tar.gz (189 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: chardet in c:\anaconda3\lib\site-packages (from charset) (4.0.0)
# Building wheels for collected packages: charset
#   Building wheel for charset (setup.py): started
#   Building wheel for charset (setup.py): finished with status 'error'
#   Running setup.py clean for charset
# Failed to build charset
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [79 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-312\charset
#       copying charset\cmd.py -> build\lib.win-amd64-cpython-312\charset
#       copying charset\__init__.py -> build\lib.win-amd64-cpython-312\charset
#       running egg_info
#       writing charset.egg-info\PKG-INFO
#       writing dependency_links to charset.egg-info\dependency_links.txt
#       writing entry points to charset.egg-info\entry_points.txt
#       writing requirements to charset.egg-info\requires.txt
#       writing top-level names to charset.egg-info\top_level.txt
#       reading manifest file 'charset.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.txt' under directory 'docs'
#       warning: no files found matching '*.txt' under directory 'languagedet\data'
#       warning: no files found matching '*.pickle' under directory 'languagedet\data'
#       warning: no files found matching '*.conf' under directory 'languagedet\data'
#       writing manifest file 'charset.egg-info\SOURCES.txt'
#       running build_ext
#       building 'charset.detector' extension
#       creating build\temp.win-amd64-cpython-312\Release\src
#       creating build\temp.win-amd64-cpython-312\Release\src\mozilladetector
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.42.34433\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Isrc/mozilladetector -IC:\anaconda3\include -IC:\anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.42.34433\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpsrc/charset.detector.cpp /Fobuild\temp.win-amd64-cpython-312\Release\src/charset.detector.obj
#       charset.detector.cpp
#       src/charset.detector.cpp(787): warning C4244: '=': 'Py_ssize_t'\xbf\xa1\xbc\xad 'int'(\xc0\xb8)\xb7\xce \xba\xafȯ\xc7ϸ鼭 \xb5\xa5\xc0\xcc\xc5Ͱ\xa1 \xbcսǵ\xc9 \xbc\xf6 \xc0ֽ\xc0\xb4ϴ\xd9.
#       src/charset.detector.cpp(2231): error C2039: 'curexc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2232): error C2039: 'curexc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2233): error C2039: 'curexc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2234): error C2039: 'curexc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2235): error C2039: 'curexc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2236): error C2039: 'curexc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2247): error C2039: 'curexc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2248): error C2039: 'curexc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2249): error C2039: 'curexc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2250): error C2039: 'curexc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2251): error C2039: 'curexc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2252): error C2039: 'curexc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2395): error C2039: 'curexc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2398): error C2039: 'curexc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2356): warning C4996: 'PyEval_CallObjectWithKeywords': deprecated in 3.9
#       src/charset.detector.cpp(2432): error C2039: 'exc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2433): error C2039: 'exc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2434): error C2039: 'exc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2446): error C2039: 'exc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2447): error C2039: 'exc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2448): error C2039: 'exc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2449): error C2039: 'exc_type': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2450): error C2039: 'exc_value': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(2451): error C2039: 'exc_traceback': '_ts'\xc0\xc7 \xb8\xe2\xb9\xf6\xb0\xa1 \xbeƴմϴ\xd9.
#       C:\anaconda3\include\cpython/pystate.h(115): note: '_ts' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(3057): error C2660: 'PyCode_New': \xc7Լ\xf6\xb4\xc2 15\xb0\xb3\xc0\xc7 \xc0μ\xf6\xb8\xa6 \xbb\xe7\xbf\xeb\xc7\xcf\xc1\xf6 \xbeʽ\xc0\xb4ϴ\xd9.
#       C:\anaconda3\include\cpython/code.h(244): note: 'PyCode_New' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       src/charset.detector.cpp(3057): note: \xc0μ\xf6 \xb8\xf1\xb7\xcf '(int, int, int, int, int, PyObject *, PyObject *, PyObject *, PyObject *, PyObject *, PyObject *, PyObject *, PyObject *, int, PyObject *)'\xc0\xbb(\xb8\xa6) \xc0\xcfġ\xbd\xc3Ű\xb4\xc2 \xb5\xbf\xbe\xc8
#       src/charset.detector.cpp(3103): error C2027: \xc1\xa4\xc0ǵ\xc7\xc1\xf6 \xbe\xca\xc0\xba \xc7\xfc\xbd\xc4 '_frame'\xc0\xbb(\xb8\xa6) \xbb\xe7\xbf\xeb\xc7߽\xc0\xb4ϴ\xd9.
#       C:\anaconda3\include\pytypedefs.h(22): note: '_frame' \xbc\xb1\xbe\xf0\xc0\xbb \xc2\xfc\xc1\xb6\xc7Ͻʽÿ\xc0.
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.42.34433\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for charset
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (charset)
# Requirement already satisfied: charset-normalizer in c:\anaconda3\lib\site-packages (3.3.2)

# %%
import folium

m = folium.Map(location=[37.53897093698831, 127.05461953077439], zoom_start = 14)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a89a8e5691809c0a0be3758ab67f203b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a89a8e5691809c0a0be3758ab67f203b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a89a8e5691809c0a0be3758ab67f203b = L.map(
#                 &quot;map_a89a8e5691809c0a0be3758ab67f203b&quot;,
#                 {
#                     center: [37.53897093698831, 127.05461953077439],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_342a3cd5c608c326ce352dc55ea897fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_342a3cd5c608c326ce352dc55ea897fe.addTo(map_a89a8e5691809c0a0be3758ab67f203b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
