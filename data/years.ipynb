# %%
import os
import json
import requests
import time
import pandas as pd
from datetime import datetime, timedelta

# Google Drive 경로 설정
base_dir = "../base/data"
save_dir = os.path.join(base_dir, "data")
os.makedirs(save_dir, exist_ok=True)

log_file = os.path.join(save_dir, "error_log.txt")

# 로그 기록 함수
def log_error(message):
    with open(log_file, "a") as f:
        f.write(f"{datetime.now()} - {message}\n")

# JSON 데이터 저장 여부 확인 함수
def is_data_saved_json(station_id, start_dt, end_dt):
    file_name = os.path.join(save_dir, f'station_{station_id}_{start_dt}_{end_dt}_filtered.json')
    return os.path.exists(file_name)

# 데이터 호출 함수
def fetch_data_with_retries(api, params):
    MAX_RETRIES = 3
    RETRY_DELAY = 2  # seconds
    retries = 0
    while retries < MAX_RETRIES:
        try:
            response = requests.get(api["url"], params=params, timeout=10)
            if response.status_code == 200:
                return response
            else:
                print(f"HTTP Error {response.status_code}: {response.text}")
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Retrying...")
        retries += 1
        time.sleep(RETRY_DELAY)
    print(f"Failed to fetch data after {MAX_RETRIES} retries.")
    return None

# 원하는 열
required_columns = ['tm', 'stnId', 'stnNm', 'ta', 'rn', 'ws', 'wd', 'hm', 'pa', 'ts']

# API 정보
apis = [
    {
        "url": "http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList",
        "key": "ZSG78Pt3T/LihB09c5HOKiwiw7Fp0YO6Zyv3IXdsG6xlAHwXn0Ujh4AI7Qusf257iRAZCZxtR6elbu64sLb2JA==",
        "limit": 10000
    },
    {
        "url": "http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList",
        "key": "sj40PraKG7dGcBNarkyuQo1EcwXDwDORJi1Hz103NVmLD4NBFkyIHBiEnGw/XnL8pKczzFOJh5+qlCtxwRCBDw==",
        "limit": 10000
    },
    {
        "url": "https://apihub.kma.go.kr/api/typ01/url/kma_sfctm2.php",
        "key": "QxivqrPbSjeYr6qz2-o3Fg",
        "limit": 20000
    }
]

# 스테이션 데이터 불러오기
station_path = os.path.join(base_dir, "station_num.csv")
station = pd.read_csv(station_path, header=None)
station_ids = station[0].tolist()

# API 호출 및 키 관리
api_index = 0
api_calls = 0

for year in range(1990, 1990 + 1): 
    print(f"Processing year: {year}")
    year_start_date = datetime(year, 1, 1)
    year_end_date = datetime(year, 12, 31)

    for station_id in station_ids:
        print(f"Processing station ID: {station_id}")
        current_date = year_start_date

        while current_date <= year_end_date:
            # API 호출 한도 초과 시 전환
            if api_calls >= apis[api_index]["limit"]:
                print(f"API limit reached for key {api_index + 1}. Switching to next key...")
                api_index = (api_index + 1) % len(apis)
                api_calls = 0
                if api_index == 0:
                    print("All keys exhausted. Waiting for reset...")
                    time.sleep(86400)  # 1일 대기

            start_dt = current_date.strftime('%Y%m%d')
            end_dt = (current_date + timedelta(days=41) - timedelta(days=1)).strftime('%Y%m%d')

            if is_data_saved_json(station_id, start_dt, end_dt):
                print(f"Filtered data already saved for station {station_id}, {start_dt} to {end_dt}. Skipping...")
                current_date += timedelta(days=41)
                continue

            params = {
                'serviceKey': apis[api_index]["key"],  # 필수: 서비스 키
                'pageNo': '1',                         # 옵션: 페이지 번호
                'numOfRows': '999',                    # 옵션: 최대 한 페이지 결과 수
                'dataType': 'JSON',                    # 옵션: JSON 형식
                'dataCd': 'ASOS',                      # 필수: 자료 코드
                'dateCd': 'HR',                        # 필수: 날짜 코드
                'startDt': start_dt,                   # 필수: 시작일 (YYYYMMDD)
                'startHh': '00',                       # 필수: 시작 시각
                'endDt': end_dt,                       # 필수: 종료일 (YYYYMMDD)
                'endHh': '23',                         # 필수: 종료 시각
                'stnIds': station_id                   # 필수: 지점 번호
            }

            response = fetch_data_with_retries(apis[api_index], params)
            api_calls += 1

            if response:
                try:
                    # JSON 데이터 필터링
                    json_data = response.json()
                    if 'response' in json_data and 'body' in json_data['response']:
                        items = json_data['response']['body']['items']['item']
                        filtered_data = [
                            {key: item[key] for key in required_columns if key in item}
                            for item in items
                        ]

                        # 필터링된 데이터 저장
                        save_path = os.path.join(save_dir, f'station_{station_id}_{start_dt}_{end_dt}_filtered.json')
                        with open(save_path, "w", encoding="utf-8") as f:
                            json.dump(filtered_data, f, ensure_ascii=False, indent=4)
                        print(f"Filtered data saved for station {station_id}, {start_dt} to {end_dt}.")
                except Exception as e:
                    log_error(f"Error filtering data for station {station_id}, {start_dt} to {end_dt}: {e}")
            else:
                log_error(f"No response received for station {station_id}, {start_dt} to {end_dt}")

            current_date += timedelta(days=41)
# Out:
# Processing year: 1990
# Processing station ID: 90
# Filtered data saved for station 90, 19900211 to 19900323.
# Filtered data saved for station 90, 19900904 to 19901014.
# Filtered data saved for station 90, 19901015 to 19901124.
# Processing station ID: 93
# Processing station ID: 95
# Filtered data saved for station 95, 19900101 to 19900210.
# Filtered data saved for station 95, 19900211 to 19900323.
# Filtered data saved for station 95, 19900324 to 19900503.
# Filtered data saved for station 95, 19900504 to 19900613.
# Filtered data saved for station 95, 19901015 to 19901124.
# Filtered data saved for station 95, 19901125 to 19910104.
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Filtered data saved for station 100, 19900614 to 19900724.
# Filtered data saved for station 100, 19901015 to 19901124.
# Processing station ID: 101
# Filtered data saved for station 101, 19900504 to 19900613.
# Filtered data saved for station 101, 19900614 to 19900724.
# Filtered data saved for station 101, 19900725 to 19900903.
# Filtered data saved for station 101, 19900904 to 19901014.
# Filtered data saved for station 101, 19901015 to 19901124.
# Filtered data saved for station 101, 19901125 to 19910104.
# Processing station ID: 102
# Processing station ID: 104
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Processing station ID: 105
# Filtered data saved for station 105, 19900725 to 19900903.
# Filtered data saved for station 105, 19900904 to 19901014.
# Filtered data saved for station 105, 19901125 to 19910104.
# Processing station ID: 106
# Processing station ID: 108
# Filtered data saved for station 108, 19900504 to 19900613.
# Filtered data saved for station 108, 19900725 to 19900903.
# Filtered data saved for station 108, 19900904 to 19901014.
# Filtered data saved for station 108, 19901015 to 19901124.
# Processing station ID: 112
# Filtered data saved for station 112, 19900101 to 19900210.
# Filtered data saved for station 112, 19900504 to 19900613.
# Filtered data saved for station 112, 19901125 to 19910104.
# Processing station ID: 114
# Filtered data saved for station 114, 19900324 to 19900503.
# Filtered data saved for station 114, 19900504 to 19900613.
# Filtered data saved for station 114, 19900614 to 19900724.
# Filtered data saved for station 114, 19901015 to 19901124.
# Processing station ID: 115
# Filtered data saved for station 115, 19900101 to 19900210.
# Filtered data saved for station 115, 19900211 to 19900323.
# Filtered data saved for station 115, 19900614 to 19900724.
# Filtered data saved for station 115, 19900725 to 19900903.
# Filtered data saved for station 115, 19901125 to 19910104.
# Processing station ID: 119
# Filtered data saved for station 119, 19900101 to 19900210.
# Filtered data saved for station 119, 19900211 to 19900323.
# Filtered data saved for station 119, 19900324 to 19900503.
# Filtered data saved for station 119, 19900614 to 19900724.
# Filtered data saved for station 119, 19900725 to 19900903.
# Filtered data saved for station 119, 19901015 to 19901124.
# Processing station ID: 121
# Processing station ID: 127
# Filtered data saved for station 127, 19900101 to 19900210.
# Filtered data saved for station 127, 19900211 to 19900323.
# Filtered data saved for station 127, 19900324 to 19900503.
# Filtered data saved for station 127, 19900504 to 19900613.
# Filtered data saved for station 127, 19900614 to 19900724.
# Filtered data saved for station 127, 19900904 to 19901014.
# Filtered data saved for station 127, 19901015 to 19901124.
# Processing station ID: 129
# Filtered data saved for station 129, 19900101 to 19900210.
# Filtered data saved for station 129, 19900504 to 19900613.
# Filtered data saved for station 129, 19900614 to 19900724.
# Processing station ID: 130
# Processing station ID: 131
# Filtered data saved for station 131, 19900904 to 19901014.
# Filtered data saved for station 131, 19901015 to 19901124.
# Filtered data saved for station 131, 19901125 to 19910104.
# Processing station ID: 133
# Filtered data saved for station 133, 19900101 to 19900210.
# Filtered data saved for station 133, 19900324 to 19900503.
# Filtered data saved for station 133, 19900504 to 19900613.
# Filtered data saved for station 133, 19900614 to 19900724.
# Filtered data saved for station 133, 19900725 to 19900903.
# Processing station ID: 135
# Filtered data saved for station 135, 19900101 to 19900210.
# Filtered data saved for station 135, 19900725 to 19900903.
# Filtered data saved for station 135, 19900904 to 19901014.
# Filtered data saved for station 135, 19901015 to 19901124.
# Filtered data saved for station 135, 19901125 to 19910104.
# Processing station ID: 136
# Filtered data saved for station 136, 19900101 to 19900210.
# Filtered data saved for station 136, 19900504 to 19900613.
# Filtered data saved for station 136, 19900614 to 19900724.
# Filtered data saved for station 136, 19900725 to 19900903.
# Filtered data saved for station 136, 19900904 to 19901014.
# Filtered data saved for station 136, 19901015 to 19901124.
# Filtered data saved for station 136, 19901125 to 19910104.
# Processing station ID: 137
# Processing station ID: 138
# Filtered data saved for station 138, 19900504 to 19900613.
# Filtered data saved for station 138, 19900614 to 19900724.
# Filtered data saved for station 138, 19900725 to 19900903.
# Filtered data saved for station 138, 19900904 to 19901014.
# Processing station ID: 140
# Filtered data saved for station 140, 19900101 to 19900210.
# Filtered data saved for station 140, 19900211 to 19900323.
# Filtered data saved for station 140, 19900324 to 19900503.
# Filtered data saved for station 140, 19900614 to 19900724.
# Filtered data saved for station 140, 19900725 to 19900903.
# Filtered data saved for station 140, 19900904 to 19901014.
# Filtered data saved for station 140, 19901015 to 19901124.
# Filtered data saved for station 140, 19901125 to 19910104.
# Processing station ID: 143
# Filtered data saved for station 143, 19900101 to 19900210.
# Filtered data saved for station 143, 19900211 to 19900323.
# Filtered data saved for station 143, 19900324 to 19900503.
# Filtered data saved for station 143, 19900504 to 19900613.
# Filtered data saved for station 143, 19900614 to 19900724.
# Filtered data saved for station 143, 19900904 to 19901014.
# Filtered data saved for station 143, 19901015 to 19901124.
# Filtered data saved for station 143, 19901125 to 19910104.
# Processing station ID: 146
# Filtered data saved for station 146, 19900211 to 19900323.
# Filtered data saved for station 146, 19900324 to 19900503.
# Processing station ID: 152
# Filtered data saved for station 152, 19900101 to 19900210.
# Filtered data saved for station 152, 19901015 to 19901124.
# Filtered data saved for station 152, 19901125 to 19910104.
# Processing station ID: 155
# Filtered data saved for station 155, 19900101 to 19900210.
# Filtered data saved for station 155, 19900504 to 19900613.
# Filtered data saved for station 155, 19900614 to 19900724.
# Filtered data saved for station 155, 19900725 to 19900903.
# Filtered data saved for station 155, 19901125 to 19910104.
# Processing station ID: 156
# Filtered data saved for station 156, 19900211 to 19900323.
# Filtered data saved for station 156, 19900324 to 19900503.
# Filtered data saved for station 156, 19900614 to 19900724.
# Filtered data saved for station 156, 19900725 to 19900903.
# Filtered data saved for station 156, 19901125 to 19910104.
# Processing station ID: 159
# Filtered data saved for station 159, 19900101 to 19900210.
# Filtered data saved for station 159, 19900324 to 19900503.
# Filtered data saved for station 159, 19900504 to 19900613.
# Filtered data saved for station 159, 19900614 to 19900724.
# Filtered data saved for station 159, 19900725 to 19900903.
# Filtered data saved for station 159, 19900904 to 19901014.
# Filtered data saved for station 159, 19901125 to 19910104.
# Processing station ID: 162
# Filtered data saved for station 162, 19900324 to 19900503.
# Filtered data saved for station 162, 19900504 to 19900613.
# Filtered data saved for station 162, 19900614 to 19900724.
# Processing station ID: 165
# Filtered data saved for station 165, 19901015 to 19901124.
# Filtered data saved for station 165, 19901125 to 19910104.
# Processing station ID: 168
# Filtered data saved for station 168, 19900101 to 19900210.
# Filtered data saved for station 168, 19900211 to 19900323.
# Filtered data saved for station 168, 19900324 to 19900503.
# Filtered data saved for station 168, 19900504 to 19900613.
# Filtered data saved for station 168, 19900614 to 19900724.
# Filtered data saved for station 168, 19900725 to 19900903.
# Filtered data saved for station 168, 19900904 to 19901014.
# Filtered data saved for station 168, 19901015 to 19901124.
# Filtered data saved for station 168, 19901125 to 19910104.
# Processing station ID: 169
# Processing station ID: 170
# Filtered data saved for station 170, 19900101 to 19900210.
# Filtered data saved for station 170, 19900324 to 19900503.
# Filtered data saved for station 170, 19900504 to 19900613.
# Filtered data saved for station 170, 19900614 to 19900724.
# Filtered data saved for station 170, 19901015 to 19901124.
# Filtered data saved for station 170, 19901125 to 19910104.
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Processing station ID: 185
# Filtered data saved for station 185, 19900211 to 19900323.
# Filtered data saved for station 185, 19900504 to 19900613.
# Filtered data saved for station 185, 19900614 to 19900724.
# Filtered data saved for station 185, 19900725 to 19900903.
# Filtered data saved for station 185, 19900904 to 19901014.
# Filtered data saved for station 185, 19901015 to 19901124.
# Processing station ID: 188
# Filtered data saved for station 188, 19900614 to 19900724.
# Filtered data saved for station 188, 19900725 to 19900903.
# Filtered data saved for station 188, 19900904 to 19901014.
# Filtered data saved for station 188, 19901015 to 19901124.
# Processing station ID: 189
# Filtered data saved for station 189, 19900101 to 19900210.
# Filtered data saved for station 189, 19900211 to 19900323.
# Filtered data saved for station 189, 19900324 to 19900503.
# Filtered data saved for station 189, 19900504 to 19900613.
# Filtered data saved for station 189, 19900614 to 19900724.
# Filtered data saved for station 189, 19900725 to 19900903.
# Filtered data saved for station 189, 19900904 to 19901014.
# Filtered data saved for station 189, 19901015 to 19901124.
# Processing station ID: 192
# Filtered data saved for station 192, 19900101 to 19900210.
# Filtered data saved for station 192, 19900211 to 19900323.
# Processing station ID: 201
# Processing station ID: 202
# Processing station ID: 203
# Filtered data saved for station 203, 19900904 to 19901014.
# Processing station ID: 211
# Filtered data saved for station 211, 19900211 to 19900323.
# Filtered data saved for station 211, 19900504 to 19900613.
# Filtered data saved for station 211, 19900904 to 19901014.
# Filtered data saved for station 211, 19901015 to 19901124.
# Filtered data saved for station 211, 19901125 to 19910104.
# Processing station ID: 212
# Filtered data saved for station 212, 19900101 to 19900210.
# Filtered data saved for station 212, 19900324 to 19900503.
# Filtered data saved for station 212, 19900504 to 19900613.
# Filtered data saved for station 212, 19900725 to 19900903.
# Filtered data saved for station 212, 19900904 to 19901014.
# Filtered data saved for station 212, 19901015 to 19901124.
# Processing station ID: 216
# Filtered data saved for station 216, 19900101 to 19900210.
# Filtered data saved for station 216, 19900211 to 19900323.
# Filtered data saved for station 216, 19900504 to 19900613.
# Filtered data saved for station 216, 19900614 to 19900724.
# Filtered data saved for station 216, 19900904 to 19901014.
# Processing station ID: 217
# Processing station ID: 221
# Filtered data saved for station 221, 19900101 to 19900210.
# Filtered data saved for station 221, 19901015 to 19901124.
# Processing station ID: 226
# Processing station ID: 232
# Processing station ID: 235
# Processing station ID: 236
# Processing station ID: 238
# Filtered data saved for station 238, 19900101 to 19900210.
# Filtered data saved for station 238, 19900211 to 19900323.
# Filtered data saved for station 238, 19900324 to 19900503.
# Filtered data saved for station 238, 19900504 to 19900613.
# Filtered data saved for station 238, 19900614 to 19900724.
# Filtered data saved for station 238, 19900725 to 19900903.
# Filtered data saved for station 238, 19901015 to 19901124.
# Processing station ID: 239
# Processing station ID: 243
# Filtered data saved for station 243, 19900101 to 19900210.
# Filtered data saved for station 243, 19900211 to 19900323.
# Filtered data saved for station 243, 19900324 to 19900503.
# Filtered data saved for station 243, 19900504 to 19900613.
# Filtered data saved for station 243, 19900614 to 19900724.
# Filtered data saved for station 243, 19901015 to 19901124.
# Filtered data saved for station 243, 19901125 to 19910104.
# Processing station ID: 244
# Filtered data saved for station 244, 19900324 to 19900503.
# Filtered data saved for station 244, 19901015 to 19901124.
# Filtered data saved for station 244, 19901125 to 19910104.
# Processing station ID: 245
# Filtered data saved for station 245, 19900211 to 19900323.
# Filtered data saved for station 245, 19900324 to 19900503.
# Processing station ID: 247
# Processing station ID: 248
# Filtered data saved for station 248, 19901015 to 19901124.
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Processing station ID: 261
# Filtered data saved for station 261, 19900904 to 19901014.
# Processing station ID: 262
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Filtered data saved for station 271, 19900101 to 19900210.
# Filtered data saved for station 271, 19900504 to 19900613.
# Filtered data saved for station 271, 19900725 to 19900903.
# Filtered data saved for station 271, 19900904 to 19901014.
# Processing station ID: 272
# Filtered data saved for station 272, 19900324 to 19900503.
# Filtered data saved for station 272, 19900504 to 19900613.
# Processing station ID: 273
# Filtered data saved for station 273, 19900101 to 19900210.
# Filtered data saved for station 273, 19900324 to 19900503.
# Filtered data saved for station 273, 19900504 to 19900613.
# Processing station ID: 276
# Processing station ID: 277
# Filtered data saved for station 277, 19900101 to 19900210.
# Filtered data saved for station 277, 19900324 to 19900503.
# Filtered data saved for station 277, 19900504 to 19900613.
# Filtered data saved for station 277, 19900614 to 19900724.
# Filtered data saved for station 277, 19900725 to 19900903.
# Processing station ID: 278
# Processing station ID: 279
# Filtered data saved for station 279, 19900725 to 19900903.
# Processing station ID: 281
# Filtered data saved for station 281, 19900101 to 19900210.
# Filtered data saved for station 281, 19900324 to 19900503.
# Filtered data saved for station 281, 19900725 to 19900903.
# Filtered data saved for station 281, 19900904 to 19901014.
# Filtered data saved for station 281, 19901015 to 19901124.
# Filtered data saved for station 281, 19901125 to 19910104.
# Processing station ID: 283
# Processing station ID: 284
# Filtered data saved for station 284, 19900101 to 19900210.
# Filtered data saved for station 284, 19900211 to 19900323.
# Filtered data saved for station 284, 19900324 to 19900503.
# Filtered data saved for station 284, 19900504 to 19900613.
# Filtered data saved for station 284, 19900725 to 19900903.
# Filtered data saved for station 284, 19900904 to 19901014.
# Filtered data saved for station 284, 19901015 to 19901124.
# Filtered data saved for station 284, 19901125 to 19910104.
# Processing station ID: 285
# Filtered data saved for station 285, 19900504 to 19900613.
# Processing station ID: 288
# Filtered data saved for station 288, 19900504 to 19900613.
# Processing station ID: 289
# Processing station ID: 294
# Filtered data saved for station 294, 19901125 to 19910104.
# Processing station ID: 295
# Filtered data saved for station 295, 19900904 to 19901014.
# Filtered data saved for station 295, 19901015 to 19901124.
# Filtered data saved for station 295, 19901125 to 19910104.

# %%
import os
import json
import requests
import time
import pandas as pd
from datetime import datetime, timedelta

# Google Drive 경로 설정
base_dir = "../base/data"
save_dir = os.path.join(base_dir, "data")
os.makedirs(save_dir, exist_ok=True)

log_file = os.path.join(save_dir, "error_log.txt")

# 로그 기록 함수
def log_error(message):
    with open(log_file, "a") as f:
        f.write(f"{datetime.now()} - {message}\n")

# JSON 데이터 저장 여부 확인 함수
def is_data_saved_json(station_id, start_dt, end_dt):
    file_name = os.path.join(save_dir, f'station_{station_id}_{start_dt}_{end_dt}_filtered.json')
    return os.path.exists(file_name)

# 데이터 호출 함수
def fetch_data_with_retries(api, params):
    MAX_RETRIES = 3
    RETRY_DELAY = 2  # seconds
    retries = 0
    while retries < MAX_RETRIES:
        try:
            response = requests.get(api["url"], params=params, timeout=10)
            if response.status_code == 200:
                return response
            else:
                print(f"HTTP Error {response.status_code}: {response.text}")
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Retrying...")
        retries += 1
        time.sleep(RETRY_DELAY)
    print(f"Failed to fetch data after {MAX_RETRIES} retries.")
    return None

# 원하는 열
required_columns = ['tm', 'stnId', 'stnNm', 'ta', 'rn', 'ws', 'wd', 'hm', 'pa', 'ts']

# API 정보
apis = [
    {
        "url": "http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList",
        "key": "ZSG78Pt3T/LihB09c5HOKiwiw7Fp0YO6Zyv3IXdsG6xlAHwXn0Ujh4AI7Qusf257iRAZCZxtR6elbu64sLb2JA==",
        "limit": 10000
    },
    {
        "url": "http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList",
        "key": "sj40PraKG7dGcBNarkyuQo1EcwXDwDORJi1Hz103NVmLD4NBFkyIHBiEnGw/XnL8pKczzFOJh5+qlCtxwRCBDw==",
        "limit": 10000
    },
    {
        "url": "https://apihub.kma.go.kr/api/typ01/url/kma_sfctm2.php",
        "key": "QxivqrPbSjeYr6qz2-o3Fg",
        "limit": 20000
    }
]

# 스테이션 데이터 불러오기
station_path = os.path.join(base_dir, "station_num.csv")
station = pd.read_csv(station_path, header=None)
station_ids = station[0].tolist()

# API 호출 및 키 관리
api_index = 0
api_calls = 0

for year in range(1991, 2000 + 1): 
    print(f"Processing year: {year}")
    year_start_date = datetime(year, 1, 1)
    year_end_date = datetime(year, 12, 31)

    for station_id in station_ids:
        print(f"Processing station ID: {station_id}")
        current_date = year_start_date

        while current_date <= year_end_date:
            # API 호출 한도 초과 시 전환
            if api_calls >= apis[api_index]["limit"]:
                print(f"API limit reached for key {api_index + 1}. Switching to next key...")
                api_index = (api_index + 1) % len(apis)
                api_calls = 0
                if api_index == 0:
                    print("All keys exhausted. Waiting for reset...")
                    time.sleep(86400)  # 1일 대기

            start_dt = current_date.strftime('%Y%m%d')
            end_dt = (current_date + timedelta(days=41) - timedelta(days=1)).strftime('%Y%m%d')

            if is_data_saved_json(station_id, start_dt, end_dt):
                print(f"Filtered data already saved for station {station_id}, {start_dt} to {end_dt}. Skipping...")
                current_date += timedelta(days=41)
                continue

            params = {
                'serviceKey': apis[api_index]["key"],  # 필수: 서비스 키
                'pageNo': '1',                         # 옵션: 페이지 번호
                'numOfRows': '999',                    # 옵션: 최대 한 페이지 결과 수
                'dataType': 'JSON',                    # 옵션: JSON 형식
                'dataCd': 'ASOS',                      # 필수: 자료 코드
                'dateCd': 'HR',                        # 필수: 날짜 코드
                'startDt': start_dt,                   # 필수: 시작일 (YYYYMMDD)
                'startHh': '00',                       # 필수: 시작 시각
                'endDt': end_dt,                       # 필수: 종료일 (YYYYMMDD)
                'endHh': '23',                         # 필수: 종료 시각
                'stnIds': station_id                   # 필수: 지점 번호
            }

            response = fetch_data_with_retries(apis[api_index], params)
            api_calls += 1

            if response:
                try:
                    # JSON 데이터 필터링
                    json_data = response.json()
                    if 'response' in json_data and 'body' in json_data['response']:
                        items = json_data['response']['body']['items']['item']
                        filtered_data = [
                            {key: item[key] for key in required_columns if key in item}
                            for item in items
                        ]

                        # 필터링된 데이터 저장
                        save_path = os.path.join(save_dir, f'station_{station_id}_{start_dt}_{end_dt}_filtered.json')
                        with open(save_path, "w", encoding="utf-8") as f:
                            json.dump(filtered_data, f, ensure_ascii=False, indent=4)
                        print(f"Filtered data saved for station {station_id}, {start_dt} to {end_dt}.")
                except Exception as e:
                    log_error(f"Error filtering data for station {station_id}, {start_dt} to {end_dt}: {e}")
            else:
                log_error(f"No response received for station {station_id}, {start_dt} to {end_dt}")

            current_date += timedelta(days=41)
# Out:
# Processing year: 1991
# Processing station ID: 90
# Processing station ID: 93
# Processing station ID: 95
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Filtered data saved for station 100, 19911015 to 19911124.
# Filtered data saved for station 100, 19911125 to 19920104.
# Processing station ID: 101
# Filtered data saved for station 101, 19910101 to 19910210.
# Filtered data saved for station 101, 19910211 to 19910323.
# Filtered data saved for station 101, 19910725 to 19910903.
# Filtered data saved for station 101, 19910904 to 19911014.
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Filtered data saved for station 105, 19910324 to 19910503.
# Filtered data saved for station 105, 19910504 to 19910613.
# Processing station ID: 106
# Processing station ID: 108
# Processing station ID: 112
# Processing station ID: 114
# Filtered data saved for station 114, 19911015 to 19911124.
# Processing station ID: 115
# Filtered data saved for station 115, 19910324 to 19910503.
# Filtered data saved for station 115, 19910504 to 19910613.
# Filtered data saved for station 115, 19910614 to 19910724.
# Filtered data saved for station 115, 19910904 to 19911014.
# Filtered data saved for station 115, 19911015 to 19911124.
# Processing station ID: 119
# Filtered data saved for station 119, 19910101 to 19910210.
# Filtered data saved for station 119, 19910211 to 19910323.
# Filtered data saved for station 119, 19910504 to 19910613.
# Filtered data saved for station 119, 19910614 to 19910724.
# Filtered data saved for station 119, 19910904 to 19911014.
# Filtered data saved for station 119, 19911015 to 19911124.
# Filtered data saved for station 119, 19911125 to 19920104.
# Processing station ID: 121
# Processing station ID: 127
# Filtered data saved for station 127, 19910101 to 19910210.
# Filtered data saved for station 127, 19910211 to 19910323.
# Filtered data saved for station 127, 19910324 to 19910503.
# Filtered data saved for station 127, 19910504 to 19910613.
# Filtered data saved for station 127, 19910904 to 19911014.
# Filtered data saved for station 127, 19911015 to 19911124.
# Processing station ID: 129
# Filtered data saved for station 129, 19910904 to 19911014.
# Filtered data saved for station 129, 19911125 to 19920104.
# Processing station ID: 130
# Filtered data saved for station 130, 19910504 to 19910613.
# Filtered data saved for station 130, 19910614 to 19910724.
# Filtered data saved for station 130, 19910725 to 19910903.
# Filtered data saved for station 130, 19910904 to 19911014.
# Filtered data saved for station 130, 19911015 to 19911124.
# Filtered data saved for station 130, 19911125 to 19920104.
# Processing station ID: 131
# Filtered data saved for station 131, 19910101 to 19910210.
# Filtered data saved for station 131, 19910211 to 19910323.
# Filtered data saved for station 131, 19910324 to 19910503.
# Filtered data saved for station 131, 19910504 to 19910613.
# Processing station ID: 133
# Filtered data saved for station 133, 19910211 to 19910323.
# Filtered data saved for station 133, 19910324 to 19910503.
# Filtered data saved for station 133, 19910614 to 19910724.
# Filtered data saved for station 133, 19910725 to 19910903.
# Filtered data saved for station 133, 19911125 to 19920104.
# Processing station ID: 135
# Filtered data saved for station 135, 19910101 to 19910210.
# Filtered data saved for station 135, 19910324 to 19910503.
# Filtered data saved for station 135, 19910504 to 19910613.
# Filtered data saved for station 135, 19910725 to 19910903.
# Filtered data saved for station 135, 19910904 to 19911014.
# Filtered data saved for station 135, 19911125 to 19920104.
# Processing station ID: 136
# Filtered data saved for station 136, 19910101 to 19910210.
# Filtered data saved for station 136, 19910504 to 19910613.
# Processing station ID: 137
# Processing station ID: 138
# Processing station ID: 140
# Processing station ID: 143
# Filtered data saved for station 143, 19910614 to 19910724.
# Filtered data saved for station 143, 19910725 to 19910903.
# Filtered data saved for station 143, 19910904 to 19911014.
# Filtered data saved for station 143, 19911015 to 19911124.
# Filtered data saved for station 143, 19911125 to 19920104.
# Processing station ID: 146
# Filtered data saved for station 146, 19910101 to 19910210.
# Filtered data saved for station 146, 19910725 to 19910903.
# Filtered data saved for station 146, 19910904 to 19911014.
# Filtered data saved for station 146, 19911015 to 19911124.
# Filtered data saved for station 146, 19911125 to 19920104.
# Processing station ID: 152
# Filtered data saved for station 152, 19910614 to 19910724.
# Filtered data saved for station 152, 19910725 to 19910903.
# Filtered data saved for station 152, 19910904 to 19911014.
# Filtered data saved for station 152, 19911125 to 19920104.
# Processing station ID: 155
# Filtered data saved for station 155, 19910324 to 19910503.
# Filtered data saved for station 155, 19910504 to 19910613.
# Filtered data saved for station 155, 19910904 to 19911014.
# Processing station ID: 156
# Filtered data saved for station 156, 19910101 to 19910210.
# Filtered data saved for station 156, 19910211 to 19910323.
# Filtered data saved for station 156, 19910324 to 19910503.
# Filtered data saved for station 156, 19910614 to 19910724.
# Filtered data saved for station 156, 19910725 to 19910903.
# Processing station ID: 159
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1360000/AsosHourlyInfoService/getWthrDataList?serviceKey=ZSG78Pt3T%2FLihB09c5HOKiwiw7Fp0YO6Zyv3IXdsG6xlAHwXn0Ujh4AI7Qusf257iRAZCZxtR6elbu64sLb2JA%3D%3D&pageNo=1&numOfRows=999&dataType=JSON&dataCd=ASOS&dateCd=HR&startDt=19911015&startHh=00&endDt=19911124&endHh=23&stnIds=159 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020A44F9EF20>, 'Connection to apis.data.go.kr timed out. (connect timeout=10)')). Retrying...
# Filtered data saved for station 159, 19911015 to 19911124.
# Filtered data saved for station 159, 19911125 to 19920104.
# Processing station ID: 162
# Filtered data saved for station 162, 19910211 to 19910323.
# Filtered data saved for station 162, 19910324 to 19910503.
# Filtered data saved for station 162, 19910614 to 19910724.
# Filtered data saved for station 162, 19910725 to 19910903.
# Filtered data saved for station 162, 19910904 to 19911014.
# Filtered data saved for station 162, 19911125 to 19920104.
# Processing station ID: 165
# Filtered data saved for station 165, 19910504 to 19910613.
# Filtered data saved for station 165, 19910614 to 19910724.
# Filtered data saved for station 165, 19910725 to 19910903.
# Filtered data saved for station 165, 19910904 to 19911014.
# Filtered data saved for station 165, 19911015 to 19911124.
# Filtered data saved for station 165, 19911125 to 19920104.
# Processing station ID: 168
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 168, 19910211 to 19910323.
# Filtered data saved for station 168, 19910324 to 19910503.
# Filtered data saved for station 168, 19910504 to 19910613.
# Processing station ID: 169
# Processing station ID: 170
# Filtered data saved for station 170, 19910725 to 19910903.
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Filtered data saved for station 184, 19910101 to 19910210.
# Filtered data saved for station 184, 19910324 to 19910503.
# Filtered data saved for station 184, 19910504 to 19910613.
# Filtered data saved for station 184, 19910614 to 19910724.
# Filtered data saved for station 184, 19910725 to 19910903.
# Filtered data saved for station 184, 19910904 to 19911014.
# Processing station ID: 185
# Filtered data saved for station 185, 19910101 to 19910210.
# Filtered data saved for station 185, 19910725 to 19910903.
# Filtered data saved for station 185, 19910904 to 19911014.
# Filtered data saved for station 185, 19911125 to 19920104.
# Processing station ID: 188
# Filtered data saved for station 188, 19910101 to 19910210.
# Filtered data saved for station 188, 19910211 to 19910323.
# Filtered data saved for station 188, 19910324 to 19910503.
# Filtered data saved for station 188, 19910504 to 19910613.
# Filtered data saved for station 188, 19910725 to 19910903.
# Filtered data saved for station 188, 19910904 to 19911014.
# Filtered data saved for station 188, 19911125 to 19920104.
# Processing station ID: 189
# Filtered data saved for station 189, 19910725 to 19910903.
# Filtered data saved for station 189, 19910904 to 19911014.
# Filtered data saved for station 189, 19911015 to 19911124.
# Filtered data saved for station 189, 19911125 to 19920104.
# Processing station ID: 192
# Filtered data saved for station 192, 19910101 to 19910210.
# Processing station ID: 201
# Processing station ID: 202
# Processing station ID: 203
# Processing station ID: 211
# Processing station ID: 212
# Filtered data saved for station 212, 19910101 to 19910210.
# Processing station ID: 216
# Processing station ID: 217
# Processing station ID: 221
# Processing station ID: 226
# Filtered data saved for station 226, 19910211 to 19910323.
# Filtered data saved for station 226, 19910904 to 19911014.
# Filtered data saved for station 226, 19911015 to 19911124.
# Processing station ID: 232
# Filtered data saved for station 232, 19910101 to 19910210.
# Filtered data saved for station 232, 19910211 to 19910323.
# Filtered data saved for station 232, 19910725 to 19910903.
# Filtered data saved for station 232, 19910904 to 19911014.
# Processing station ID: 235
# Filtered data saved for station 235, 19910101 to 19910210.
# Filtered data saved for station 235, 19910211 to 19910323.
# Filtered data saved for station 235, 19910504 to 19910613.
# Filtered data saved for station 235, 19910614 to 19910724.
# Filtered data saved for station 235, 19910725 to 19910903.
# Filtered data saved for station 235, 19910904 to 19911014.
# Processing station ID: 236
# Filtered data saved for station 236, 19910101 to 19910210.
# Filtered data saved for station 236, 19911015 to 19911124.
# Filtered data saved for station 236, 19911125 to 19920104.
# Processing station ID: 238
# Filtered data saved for station 238, 19910614 to 19910724.
# Filtered data saved for station 238, 19910725 to 19910903.
# Filtered data saved for station 238, 19911125 to 19920104.
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Processing station ID: 245
# Filtered data saved for station 245, 19910725 to 19910903.
# Processing station ID: 247
# Processing station ID: 248
# Filtered data saved for station 248, 19910904 to 19911014.
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Filtered data saved for station 260, 19910725 to 19910903.
# Filtered data saved for station 260, 19911015 to 19911124.
# Processing station ID: 261
# Filtered data saved for station 261, 19910324 to 19910503.
# Filtered data saved for station 261, 19910725 to 19910903.
# Filtered data saved for station 261, 19910904 to 19911014.
# Filtered data saved for station 261, 19911125 to 19920104.
# Processing station ID: 262
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Processing station ID: 272
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Processing station ID: 278
# Filtered data saved for station 278, 19910904 to 19911014.
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 278, 19911015 to 19911124.
# Filtered data saved for station 278, 19911125 to 19920104.
# Processing station ID: 279
# Filtered data saved for station 279, 19910324 to 19910503.
# Filtered data saved for station 279, 19910504 to 19910613.
# Filtered data saved for station 279, 19910614 to 19910724.
# Filtered data saved for station 279, 19910904 to 19911014.
# Filtered data saved for station 279, 19911125 to 19920104.
# Processing station ID: 281
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Processing station ID: 288
# Processing station ID: 289
# Processing station ID: 294
# Processing station ID: 295
# Processing year: 1992
# Processing station ID: 90
# Processing station ID: 93
# Processing station ID: 95
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Filtered data saved for station 100, 19920211 to 19920322.
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 100, 19920613 to 19920723.
# Filtered data saved for station 100, 19921014 to 19921123.
# Filtered data saved for station 100, 19921124 to 19930103.
# Processing station ID: 101
# Filtered data saved for station 101, 19920101 to 19920210.
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Processing station ID: 106
# Processing station ID: 108
# Processing station ID: 112
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1360000/AsosHourlyInfoService/getWthrDataList?serviceKey=ZSG78Pt3T%2FLihB09c5HOKiwiw7Fp0YO6Zyv3IXdsG6xlAHwXn0Ujh4AI7Qusf257iRAZCZxtR6elbu64sLb2JA%3D%3D&pageNo=1&numOfRows=999&dataType=JSON&dataCd=ASOS&dateCd=HR&startDt=19920724&startHh=00&endDt=19920902&endHh=23&stnIds=112 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020A44F9E9E0>, 'Connection to apis.data.go.kr timed out. (connect timeout=10)')). Retrying...
# Filtered data saved for station 112, 19920724 to 19920902.
# Filtered data saved for station 112, 19921014 to 19921123.
# Filtered data saved for station 112, 19921124 to 19930103.
# Processing station ID: 114
# Filtered data saved for station 114, 19920323 to 19920502.
# Filtered data saved for station 114, 19920503 to 19920612.
# Filtered data saved for station 114, 19920724 to 19920902.
# Filtered data saved for station 114, 19921014 to 19921123.
# Filtered data saved for station 114, 19921124 to 19930103.
# Processing station ID: 115
# Filtered data saved for station 115, 19920101 to 19920210.
# Filtered data saved for station 115, 19920613 to 19920723.
# Filtered data saved for station 115, 19920903 to 19921013.
# Processing station ID: 119
# Processing station ID: 121
# Processing station ID: 127
# Processing station ID: 129
# Processing station ID: 130
# Processing station ID: 131
# Processing station ID: 133
# Processing station ID: 135
# Processing station ID: 136
# Filtered data saved for station 136, 19920211 to 19920322.
# Filtered data saved for station 136, 19920323 to 19920502.
# Filtered data saved for station 136, 19920503 to 19920612.
# Filtered data saved for station 136, 19920613 to 19920723.
# Filtered data saved for station 136, 19920903 to 19921013.
# Filtered data saved for station 136, 19921124 to 19930103.
# Processing station ID: 137
# Processing station ID: 138
# Filtered data saved for station 138, 19920101 to 19920210.
# Filtered data saved for station 138, 19920211 to 19920322.
# Filtered data saved for station 138, 19920503 to 19920612.
# Filtered data saved for station 138, 19921014 to 19921123.
# Processing station ID: 140
# Filtered data saved for station 140, 19920101 to 19920210.
# Filtered data saved for station 140, 19920211 to 19920322.
# Filtered data saved for station 140, 19920323 to 19920502.
# Filtered data saved for station 140, 19920503 to 19920612.
# Filtered data saved for station 140, 19920613 to 19920723.
# Filtered data saved for station 140, 19920724 to 19920902.
# Filtered data saved for station 140, 19921014 to 19921123.
# Filtered data saved for station 140, 19921124 to 19930103.
# Processing station ID: 143
# Filtered data saved for station 143, 19920101 to 19920210.
# Filtered data saved for station 143, 19920211 to 19920322.
# Filtered data saved for station 143, 19920613 to 19920723.
# Processing station ID: 146
# Processing station ID: 152
# Processing station ID: 155
# Processing station ID: 156
# Processing station ID: 159
# Processing station ID: 162
# Processing station ID: 165
# Processing station ID: 168
# Processing station ID: 169
# Processing station ID: 170
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Processing station ID: 185
# Filtered data saved for station 185, 19920724 to 19920902.
# Filtered data saved for station 185, 19921014 to 19921123.
# Processing station ID: 188
# Filtered data saved for station 188, 19920101 to 19920210.
# Filtered data saved for station 188, 19920323 to 19920502.
# Filtered data saved for station 188, 19920503 to 19920612.
# Filtered data saved for station 188, 19920613 to 19920723.
# Filtered data saved for station 188, 19920724 to 19920902.
# Filtered data saved for station 188, 19920903 to 19921013.
# Filtered data saved for station 188, 19921014 to 19921123.
# Processing station ID: 189
# Filtered data saved for station 189, 19920101 to 19920210.
# Filtered data saved for station 189, 19920323 to 19920502.
# Filtered data saved for station 189, 19920503 to 19920612.
# Filtered data saved for station 189, 19920903 to 19921013.
# Processing station ID: 192
# Filtered data saved for station 192, 19920101 to 19920210.
# Filtered data saved for station 192, 19920211 to 19920322.
# Filtered data saved for station 192, 19920323 to 19920502.
# Processing station ID: 201
# Processing station ID: 202
# Processing station ID: 203
# Processing station ID: 211
# Processing station ID: 212
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 212, 19920724 to 19920902.
# Filtered data saved for station 212, 19920903 to 19921013.
# Filtered data saved for station 212, 19921124 to 19930103.
# Processing station ID: 216
# Filtered data saved for station 216, 19920101 to 19920210.
# Filtered data saved for station 216, 19920503 to 19920612.
# Filtered data saved for station 216, 19920613 to 19920723.
# Filtered data saved for station 216, 19920724 to 19920902.
# Filtered data saved for station 216, 19921124 to 19930103.
# Processing station ID: 217
# Processing station ID: 221
# Filtered data saved for station 221, 19920101 to 19920210.
# Filtered data saved for station 221, 19920323 to 19920502.
# Filtered data saved for station 221, 19920903 to 19921013.
# Processing station ID: 226
# Filtered data saved for station 226, 19920503 to 19920612.
# Filtered data saved for station 226, 19920613 to 19920723.
# Filtered data saved for station 226, 19920724 to 19920902.
# Filtered data saved for station 226, 19921014 to 19921123.
# Filtered data saved for station 226, 19921124 to 19930103.
# Processing station ID: 232
# Filtered data saved for station 232, 19920724 to 19920902.
# Filtered data saved for station 232, 19920903 to 19921013.
# Filtered data saved for station 232, 19921124 to 19930103.
# Processing station ID: 235
# Processing station ID: 236
# Processing station ID: 238
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Processing station ID: 245
# Processing station ID: 247
# Processing station ID: 248
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Filtered data saved for station 260, 19920101 to 19920210.
# Filtered data saved for station 260, 19920323 to 19920502.
# Filtered data saved for station 260, 19920503 to 19920612.
# Filtered data saved for station 260, 19920724 to 19920902.
# Filtered data saved for station 260, 19920903 to 19921013.
# Processing station ID: 261
# Filtered data saved for station 261, 19920323 to 19920502.
# Filtered data saved for station 261, 19920503 to 19920612.
# Filtered data saved for station 261, 19920724 to 19920902.
# Filtered data saved for station 261, 19920903 to 19921013.
# Filtered data saved for station 261, 19921014 to 19921123.
# Filtered data saved for station 261, 19921124 to 19930103.
# Processing station ID: 262
# Filtered data saved for station 262, 19920211 to 19920322.
# Filtered data saved for station 262, 19920323 to 19920502.
# Filtered data saved for station 262, 19920613 to 19920723.
# Filtered data saved for station 262, 19920903 to 19921013.
# Filtered data saved for station 262, 19921014 to 19921123.
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Processing station ID: 272
# Processing station ID: 273
# Filtered data saved for station 273, 19920613 to 19920723.
# Processing station ID: 276
# Processing station ID: 277
# Processing station ID: 278
# Processing station ID: 279
# Filtered data saved for station 279, 19920613 to 19920723.
# Processing station ID: 281
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Filtered data saved for station 285, 19920323 to 19920502.
# Filtered data saved for station 285, 19921124 to 19930103.
# Processing station ID: 288
# Filtered data saved for station 288, 19920101 to 19920210.
# Filtered data saved for station 288, 19920211 to 19920322.
# Filtered data saved for station 288, 19920323 to 19920502.
# Filtered data saved for station 288, 19920724 to 19920902.
# Filtered data saved for station 288, 19920903 to 19921013.
# Filtered data saved for station 288, 19921014 to 19921123.
# Processing station ID: 289
# Filtered data saved for station 289, 19920101 to 19920210.
# Filtered data saved for station 289, 19920211 to 19920322.
# Filtered data saved for station 289, 19920323 to 19920502.
# Filtered data saved for station 289, 19920724 to 19920902.
# Filtered data saved for station 289, 19921124 to 19930103.
# Processing station ID: 294
# Filtered data saved for station 294, 19920101 to 19920210.
# Filtered data saved for station 294, 19920211 to 19920322.
# Filtered data saved for station 294, 19920613 to 19920723.
# Filtered data saved for station 294, 19920903 to 19921013.
# Filtered data saved for station 294, 19921014 to 19921123.
# Filtered data saved for station 294, 19921124 to 19930103.
# Processing station ID: 295
# Filtered data saved for station 295, 19920101 to 19920210.
# Filtered data saved for station 295, 19920613 to 19920723.
# Filtered data saved for station 295, 19921014 to 19921123.
# Processing year: 1993
# Processing station ID: 90
# Processing station ID: 93
# Processing station ID: 95
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Processing station ID: 101
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Processing station ID: 106
# Processing station ID: 108
# Processing station ID: 112
# Processing station ID: 114
# Processing station ID: 115
# Filtered data saved for station 115, 19930211 to 19930323.
# Filtered data saved for station 115, 19930504 to 19930613.
# Processing station ID: 119
# Filtered data saved for station 119, 19930211 to 19930323.
# Filtered data saved for station 119, 19930324 to 19930503.
# Filtered data saved for station 119, 19930725 to 19930903.
# Filtered data saved for station 119, 19930904 to 19931014.
# Filtered data saved for station 119, 19931015 to 19931124.
# Filtered data saved for station 119, 19931125 to 19940104.
# Processing station ID: 121
# Processing station ID: 127
# Filtered data saved for station 127, 19930614 to 19930724.
# Filtered data saved for station 127, 19931015 to 19931124.
# Filtered data saved for station 127, 19931125 to 19940104.
# Processing station ID: 129
# Filtered data saved for station 129, 19930101 to 19930210.
# Filtered data saved for station 129, 19930614 to 19930724.
# Filtered data saved for station 129, 19930725 to 19930903.
# Filtered data saved for station 129, 19930904 to 19931014.
# Filtered data saved for station 129, 19931015 to 19931124.
# Processing station ID: 130
# Processing station ID: 131
# Processing station ID: 133
# Processing station ID: 135
# Processing station ID: 136
# Processing station ID: 137
# Processing station ID: 138
# Processing station ID: 140
# Processing station ID: 143
# Processing station ID: 146
# Processing station ID: 152
# Processing station ID: 155
# Processing station ID: 156
# Filtered data saved for station 156, 19930725 to 19930903.
# Filtered data saved for station 156, 19931015 to 19931124.
# Filtered data saved for station 156, 19931125 to 19940104.
# Processing station ID: 159
# Filtered data saved for station 159, 19930211 to 19930323.
# Filtered data saved for station 159, 19930614 to 19930724.
# Filtered data saved for station 159, 19930725 to 19930903.
# Filtered data saved for station 159, 19930904 to 19931014.
# Filtered data saved for station 159, 19931015 to 19931124.
# Filtered data saved for station 159, 19931125 to 19940104.
# Processing station ID: 162
# Filtered data saved for station 162, 19930101 to 19930210.
# Filtered data saved for station 162, 19930211 to 19930323.
# Filtered data saved for station 162, 19930504 to 19930613.
# Filtered data saved for station 162, 19930614 to 19930724.
# Filtered data saved for station 162, 19930725 to 19930903.
# Filtered data saved for station 162, 19931125 to 19940104.
# Processing station ID: 165
# Filtered data saved for station 165, 19930324 to 19930503.
# Processing station ID: 168
# Filtered data saved for station 168, 19930101 to 19930210.
# Filtered data saved for station 168, 19930211 to 19930323.
# Filtered data saved for station 168, 19930904 to 19931014.
# Filtered data saved for station 168, 19931125 to 19940104.
# Processing station ID: 169
# Processing station ID: 170
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Processing station ID: 185
# Processing station ID: 188
# Processing station ID: 189
# Processing station ID: 192
# Processing station ID: 201
# Filtered data saved for station 201, 19931125 to 19940104.
# Processing station ID: 202
# Processing station ID: 203
# Processing station ID: 211
# Filtered data saved for station 211, 19930904 to 19931014.
# Processing station ID: 212
# Filtered data saved for station 212, 19930101 to 19930210.
# Filtered data saved for station 212, 19930725 to 19930903.
# Filtered data saved for station 212, 19930904 to 19931014.
# Filtered data saved for station 212, 19931015 to 19931124.
# Processing station ID: 216
# Filtered data saved for station 216, 19930101 to 19930210.
# Filtered data saved for station 216, 19930211 to 19930323.
# Filtered data saved for station 216, 19930904 to 19931014.
# Processing station ID: 217
# Processing station ID: 221
# Filtered data saved for station 221, 19930324 to 19930503.
# Filtered data saved for station 221, 19930504 to 19930613.
# Filtered data saved for station 221, 19930614 to 19930724.
# Filtered data saved for station 221, 19930904 to 19931014.
# Filtered data saved for station 221, 19931125 to 19940104.
# Processing station ID: 226
# Filtered data saved for station 226, 19930101 to 19930210.
# Filtered data saved for station 226, 19930504 to 19930613.
# Filtered data saved for station 226, 19930614 to 19930724.
# Filtered data saved for station 226, 19931015 to 19931124.
# Processing station ID: 232
# Filtered data saved for station 232, 19930211 to 19930323.
# Filtered data saved for station 232, 19930324 to 19930503.
# Processing station ID: 235
# Processing station ID: 236
# Processing station ID: 238
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Processing station ID: 245
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 245, 19930324 to 19930503.
# Filtered data saved for station 245, 19930504 to 19930613.
# Filtered data saved for station 245, 19930614 to 19930724.
# Filtered data saved for station 245, 19930725 to 19930903.
# Filtered data saved for station 245, 19931125 to 19940104.
# Processing station ID: 247
# Filtered data saved for station 247, 19930101 to 19930210.
# Filtered data saved for station 247, 19930211 to 19930323.
# Filtered data saved for station 247, 19930504 to 19930613.
# Filtered data saved for station 247, 19930725 to 19930903.
# Filtered data saved for station 247, 19930904 to 19931014.
# Filtered data saved for station 247, 19931015 to 19931124.
# Filtered data saved for station 247, 19931125 to 19940104.
# Processing station ID: 248
# Filtered data saved for station 248, 19930324 to 19930503.
# Filtered data saved for station 248, 19930904 to 19931014.
# Filtered data saved for station 248, 19931125 to 19940104.
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Processing station ID: 261
# Filtered data saved for station 261, 19931125 to 19940104.
# Processing station ID: 262
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Processing station ID: 272
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Filtered data saved for station 277, 19930324 to 19930503.
# Filtered data saved for station 277, 19930904 to 19931014.
# Filtered data saved for station 277, 19931125 to 19940104.
# Processing station ID: 278
# Filtered data saved for station 278, 19930101 to 19930210.
# Filtered data saved for station 278, 19930211 to 19930323.
# Filtered data saved for station 278, 19930504 to 19930613.
# Filtered data saved for station 278, 19930614 to 19930724.
# Filtered data saved for station 278, 19930725 to 19930903.
# Filtered data saved for station 278, 19931015 to 19931124.
# Filtered data saved for station 278, 19931125 to 19940104.
# Processing station ID: 279
# Filtered data saved for station 279, 19930211 to 19930323.
# Filtered data saved for station 279, 19930324 to 19930503.
# Filtered data saved for station 279, 19930504 to 19930613.
# Filtered data saved for station 279, 19930614 to 19930724.
# Filtered data saved for station 279, 19930725 to 19930903.
# Filtered data saved for station 279, 19931015 to 19931124.
# Filtered data saved for station 279, 19931125 to 19940104.
# Processing station ID: 281
# Filtered data saved for station 281, 19930904 to 19931014.
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Processing station ID: 288
# Processing station ID: 289
# Processing station ID: 294
# Processing station ID: 295
# Processing year: 1994
# Processing station ID: 90
# Processing station ID: 93
# Processing station ID: 95
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Processing station ID: 101
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Processing station ID: 106
# Filtered data saved for station 106, 19941015 to 19941124.
# Processing station ID: 108
# Filtered data saved for station 108, 19940101 to 19940210.
# Filtered data saved for station 108, 19940324 to 19940503.
# Filtered data saved for station 108, 19940504 to 19940613.
# Filtered data saved for station 108, 19940614 to 19940724.
# Filtered data saved for station 108, 19940725 to 19940903.
# Filtered data saved for station 108, 19940904 to 19941014.
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 108, 19941125 to 19950104.
# Processing station ID: 112
# Filtered data saved for station 112, 19940324 to 19940503.
# Processing station ID: 114
# Processing station ID: 115
# Filtered data saved for station 115, 19940211 to 19940323.
# Processing station ID: 119
# Processing station ID: 121
# Processing station ID: 127
# Processing station ID: 129
# Processing station ID: 130
# Processing station ID: 131
# Processing station ID: 133
# Processing station ID: 135
# Filtered data saved for station 135, 19940904 to 19941014.
# Filtered data saved for station 135, 19941125 to 19950104.
# Processing station ID: 136
# Filtered data saved for station 136, 19940504 to 19940613.
# Filtered data saved for station 136, 19940614 to 19940724.
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 136, 19940904 to 19941014.
# Filtered data saved for station 136, 19941015 to 19941124.
# Filtered data saved for station 136, 19941125 to 19950104.
# Processing station ID: 137
# Processing station ID: 138
# Filtered data saved for station 138, 19940101 to 19940210.
# Filtered data saved for station 138, 19940614 to 19940724.
# Filtered data saved for station 138, 19940904 to 19941014.
# Processing station ID: 140
# Filtered data saved for station 140, 19940324 to 19940503.
# Filtered data saved for station 140, 19940504 to 19940613.
# Processing station ID: 143
# Processing station ID: 146
# Processing station ID: 152
# Filtered data saved for station 152, 19941015 to 19941124.
# Processing station ID: 155
# Processing station ID: 156
# Processing station ID: 159
# Processing station ID: 162
# Processing station ID: 165
# Filtered data saved for station 165, 19940725 to 19940903.
# Processing station ID: 168
# Filtered data saved for station 168, 19940101 to 19940210.
# Filtered data saved for station 168, 19940211 to 19940323.
# Filtered data saved for station 168, 19940504 to 19940613.
# Filtered data saved for station 168, 19940614 to 19940724.
# Filtered data saved for station 168, 19940725 to 19940903.
# Filtered data saved for station 168, 19941015 to 19941124.
# Processing station ID: 169
# Processing station ID: 170
# Filtered data saved for station 170, 19940211 to 19940323.
# Filtered data saved for station 170, 19940504 to 19940613.
# Filtered data saved for station 170, 19940614 to 19940724.
# Filtered data saved for station 170, 19940725 to 19940903.
# Filtered data saved for station 170, 19941125 to 19950104.
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Filtered data saved for station 184, 19940101 to 19940210.
# Filtered data saved for station 184, 19940211 to 19940323.
# Processing station ID: 185
# Processing station ID: 188
# Processing station ID: 189
# Processing station ID: 192
# Processing station ID: 201
# Filtered data saved for station 201, 19940725 to 19940903.
# Processing station ID: 202
# Processing station ID: 203
# Processing station ID: 211
# Filtered data saved for station 211, 19940211 to 19940323.
# Processing station ID: 212
# Processing station ID: 216
# Processing station ID: 217
# Processing station ID: 221
# Processing station ID: 226
# Filtered data saved for station 226, 19940101 to 19940210.
# Filtered data saved for station 226, 19940504 to 19940613.
# Filtered data saved for station 226, 19940614 to 19940724.
# Filtered data saved for station 226, 19940725 to 19940903.
# Filtered data saved for station 226, 19941015 to 19941124.
# Processing station ID: 232
# Filtered data saved for station 232, 19940324 to 19940503.
# Filtered data saved for station 232, 19940504 to 19940613.
# Filtered data saved for station 232, 19940614 to 19940724.
# Filtered data saved for station 232, 19940904 to 19941014.
# Filtered data saved for station 232, 19941015 to 19941124.
# Filtered data saved for station 232, 19941125 to 19950104.
# Processing station ID: 235
# Filtered data saved for station 235, 19940324 to 19940503.
# Filtered data saved for station 235, 19940904 to 19941014.
# Filtered data saved for station 235, 19941015 to 19941124.
# Filtered data saved for station 235, 19941125 to 19950104.
# Processing station ID: 236
# Filtered data saved for station 236, 19940101 to 19940210.
# Filtered data saved for station 236, 19940324 to 19940503.
# Filtered data saved for station 236, 19940504 to 19940613.
# Filtered data saved for station 236, 19940614 to 19940724.
# Filtered data saved for station 236, 19940725 to 19940903.
# Filtered data saved for station 236, 19941125 to 19950104.
# Processing station ID: 238
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Processing station ID: 245
# Processing station ID: 247
# Processing station ID: 248
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Filtered data saved for station 260, 19940101 to 19940210.
# Filtered data saved for station 260, 19940324 to 19940503.
# Filtered data saved for station 260, 19940725 to 19940903.
# Filtered data saved for station 260, 19940904 to 19941014.
# Filtered data saved for station 260, 19941125 to 19950104.
# Processing station ID: 261
# Filtered data saved for station 261, 19940504 to 19940613.
# Filtered data saved for station 261, 19940614 to 19940724.
# Filtered data saved for station 261, 19940725 to 19940903.
# Processing station ID: 262
# Filtered data saved for station 262, 19940211 to 19940323.
# Filtered data saved for station 262, 19941015 to 19941124.
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Filtered data saved for station 271, 19940211 to 19940323.
# Filtered data saved for station 271, 19940614 to 19940724.
# Processing station ID: 272
# Filtered data saved for station 272, 19940101 to 19940210.
# Filtered data saved for station 272, 19940504 to 19940613.
# Filtered data saved for station 272, 19940614 to 19940724.
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Processing station ID: 278
# Processing station ID: 279
# Processing station ID: 281
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Processing station ID: 288
# Processing station ID: 289
# Filtered data saved for station 289, 19940324 to 19940503.
# Filtered data saved for station 289, 19940504 to 19940613.
# Filtered data saved for station 289, 19940904 to 19941014.
# Processing station ID: 294
# Filtered data saved for station 294, 19940504 to 19940613.
# Filtered data saved for station 294, 19940725 to 19940903.
# Filtered data saved for station 294, 19940904 to 19941014.
# Filtered data saved for station 294, 19941015 to 19941124.
# Filtered data saved for station 294, 19941125 to 19950104.
# Processing station ID: 295
# Filtered data saved for station 295, 19940101 to 19940210.
# Filtered data saved for station 295, 19940211 to 19940323.
# Filtered data saved for station 295, 19940324 to 19940503.
# Filtered data saved for station 295, 19940504 to 19940613.
# Filtered data saved for station 295, 19941015 to 19941124.
# Filtered data saved for station 295, 19941125 to 19950104.
# Processing year: 1995
# Processing station ID: 90
# Filtered data saved for station 90, 19950101 to 19950210.
# Filtered data saved for station 90, 19950504 to 19950613.
# Filtered data saved for station 90, 19950614 to 19950724.
# Filtered data saved for station 90, 19950725 to 19950903.
# Processing station ID: 93
# Processing station ID: 95
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Processing station ID: 101
# Filtered data saved for station 101, 19950614 to 19950724.
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Processing station ID: 106
# Processing station ID: 108
# Processing station ID: 112
# Processing station ID: 114
# Processing station ID: 115
# Filtered data saved for station 115, 19950504 to 19950613.
# Filtered data saved for station 115, 19950904 to 19951014.
# Filtered data saved for station 115, 19951015 to 19951124.
# Filtered data saved for station 115, 19951125 to 19960104.
# Processing station ID: 119
# Filtered data saved for station 119, 19950101 to 19950210.
# Filtered data saved for station 119, 19950324 to 19950503.
# Processing station ID: 121
# Filtered data saved for station 121, 19950211 to 19950323.
# Filtered data saved for station 121, 19950324 to 19950503.
# Filtered data saved for station 121, 19950904 to 19951014.
# Filtered data saved for station 121, 19951015 to 19951124.
# Filtered data saved for station 121, 19951125 to 19960104.
# Processing station ID: 127
# Filtered data saved for station 127, 19950504 to 19950613.
# Filtered data saved for station 127, 19950614 to 19950724.
# Filtered data saved for station 127, 19951015 to 19951124.
# Processing station ID: 129
# Filtered data saved for station 129, 19950101 to 19950210.
# Filtered data saved for station 129, 19950324 to 19950503.
# Processing station ID: 130
# Processing station ID: 131
# Processing station ID: 133
# Processing station ID: 135
# Processing station ID: 136
# Processing station ID: 137
# Processing station ID: 138
# Processing station ID: 140
# Processing station ID: 143
# Processing station ID: 146
# Filtered data saved for station 146, 19950614 to 19950724.
# Processing station ID: 152
# Processing station ID: 155
# Processing station ID: 156
# Processing station ID: 159
# Filtered data saved for station 159, 19950904 to 19951014.
# Filtered data saved for station 159, 19951125 to 19960104.
# Processing station ID: 162
# Filtered data saved for station 162, 19950211 to 19950323.
# Filtered data saved for station 162, 19950504 to 19950613.
# Filtered data saved for station 162, 19950904 to 19951014.
# Filtered data saved for station 162, 19951015 to 19951124.
# Processing station ID: 165
# Filtered data saved for station 165, 19950101 to 19950210.
# Filtered data saved for station 165, 19950211 to 19950323.
# Filtered data saved for station 165, 19950904 to 19951014.
# Filtered data saved for station 165, 19951015 to 19951124.
# Processing station ID: 168
# Filtered data saved for station 168, 19950101 to 19950210.
# Filtered data saved for station 168, 19950211 to 19950323.
# Filtered data saved for station 168, 19950324 to 19950503.
# Filtered data saved for station 168, 19950504 to 19950613.
# Filtered data saved for station 168, 19950904 to 19951014.
# Filtered data saved for station 168, 19951015 to 19951124.
# Filtered data saved for station 168, 19951125 to 19960104.
# Processing station ID: 169
# Processing station ID: 170
# Filtered data saved for station 170, 19950211 to 19950323.
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Processing station ID: 185
# Processing station ID: 188
# Processing station ID: 189
# Processing station ID: 192
# Processing station ID: 201
# Processing station ID: 202
# Filtered data saved for station 202, 19950614 to 19950724.
# Processing station ID: 203
# Processing station ID: 211
# Processing station ID: 212
# Filtered data saved for station 212, 19951015 to 19951124.
# Filtered data saved for station 212, 19951125 to 19960104.
# Processing station ID: 216
# Filtered data saved for station 216, 19950324 to 19950503.
# Filtered data saved for station 216, 19950504 to 19950613.
# Filtered data saved for station 216, 19950904 to 19951014.
# Processing station ID: 217
# Processing station ID: 221
# Filtered data saved for station 221, 19950101 to 19950210.
# Filtered data saved for station 221, 19950211 to 19950323.
# Filtered data saved for station 221, 19950324 to 19950503.
# Filtered data saved for station 221, 19950504 to 19950613.
# Filtered data saved for station 221, 19951015 to 19951124.
# Filtered data saved for station 221, 19951125 to 19960104.
# Processing station ID: 226
# Filtered data saved for station 226, 19950101 to 19950210.
# Filtered data saved for station 226, 19950211 to 19950323.
# Filtered data saved for station 226, 19950324 to 19950503.
# Filtered data saved for station 226, 19950725 to 19950903.
# Filtered data saved for station 226, 19950904 to 19951014.
# Processing station ID: 232
# Filtered data saved for station 232, 19950211 to 19950323.
# Filtered data saved for station 232, 19950614 to 19950724.
# Filtered data saved for station 232, 19950725 to 19950903.
# Filtered data saved for station 232, 19950904 to 19951014.
# Processing station ID: 235
# Processing station ID: 236
# Processing station ID: 238
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Processing station ID: 245
# Processing station ID: 247
# Processing station ID: 248
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Filtered data saved for station 260, 19950101 to 19950210.
# Filtered data saved for station 260, 19950211 to 19950323.
# Filtered data saved for station 260, 19951125 to 19960104.
# Processing station ID: 261
# Filtered data saved for station 261, 19950101 to 19950210.
# Filtered data saved for station 261, 19950324 to 19950503.
# Filtered data saved for station 261, 19950504 to 19950613.
# Filtered data saved for station 261, 19951015 to 19951124.
# Processing station ID: 262
# Filtered data saved for station 262, 19950324 to 19950503.
# Filtered data saved for station 262, 19950904 to 19951014.
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Filtered data saved for station 271, 19950101 to 19950210.
# Filtered data saved for station 271, 19950211 to 19950323.
# Filtered data saved for station 271, 19950324 to 19950503.
# Filtered data saved for station 271, 19950504 to 19950613.
# Filtered data saved for station 271, 19950725 to 19950903.
# Processing station ID: 272
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Processing station ID: 278
# Processing station ID: 279
# Processing station ID: 281
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Processing station ID: 288
# Filtered data saved for station 288, 19950101 to 19950210.
# Processing station ID: 289
# Processing station ID: 294
# Filtered data saved for station 294, 19951125 to 19960104.
# Processing station ID: 295
# Filtered data saved for station 295, 19950324 to 19950503.
# Filtered data saved for station 295, 19950614 to 19950724.
# Filtered data saved for station 295, 19950725 to 19950903.
# Filtered data saved for station 295, 19951015 to 19951124.
# Filtered data saved for station 295, 19951125 to 19960104.
# Processing year: 1996
# Processing station ID: 90
# Filtered data saved for station 90, 19960101 to 19960210.
# Filtered data saved for station 90, 19960211 to 19960322.
# Filtered data saved for station 90, 19960323 to 19960502.
# Filtered data saved for station 90, 19960503 to 19960612.
# Filtered data saved for station 90, 19960724 to 19960902.
# Filtered data saved for station 90, 19960903 to 19961013.
# Filtered data saved for station 90, 19961124 to 19970103.
# Processing station ID: 93
# Processing station ID: 95
# Filtered data saved for station 95, 19960211 to 19960322.
# Filtered data saved for station 95, 19960613 to 19960723.
# Processing station ID: 98
# Processing station ID: 99
# Processing station ID: 100
# Processing station ID: 101
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Filtered data saved for station 105, 19961124 to 19970103.
# Processing station ID: 106
# Filtered data saved for station 106, 19960724 to 19960902.
# Processing station ID: 108
# Filtered data saved for station 108, 19960613 to 19960723.
# Filtered data saved for station 108, 19960724 to 19960902.
# Filtered data saved for station 108, 19961014 to 19961123.
# Processing station ID: 112
# Filtered data saved for station 112, 19960613 to 19960723.
# Filtered data saved for station 112, 19960903 to 19961013.
# Filtered data saved for station 112, 19961014 to 19961123.
# Processing station ID: 114
# Filtered data saved for station 114, 19960101 to 19960210.
# Filtered data saved for station 114, 19960211 to 19960322.
# Filtered data saved for station 114, 19960323 to 19960502.
# Filtered data saved for station 114, 19960503 to 19960612.
# Filtered data saved for station 114, 19960613 to 19960723.
# Filtered data saved for station 114, 19960903 to 19961013.
# Filtered data saved for station 114, 19961014 to 19961123.
# Filtered data saved for station 114, 19961124 to 19970103.
# Processing station ID: 115
# Filtered data saved for station 115, 19960503 to 19960612.
# Filtered data saved for station 115, 19960724 to 19960902.
# Filtered data saved for station 115, 19961014 to 19961123.
# Processing station ID: 119
# Processing station ID: 121
# Processing station ID: 127
# Processing station ID: 129
# Processing station ID: 130
# Processing station ID: 131
# Processing station ID: 133
# Processing station ID: 135
# Processing station ID: 136
# ...
# Filtered data saved for station 245, 19980614 to 19980724.
# Processing station ID: 247
# Filtered data saved for station 247, 19981015 to 19981124.
# Processing station ID: 248
# Filtered data saved for station 248, 19981015 to 19981124.
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Filtered data saved for station 260, 19980211 to 19980323.
# Filtered data saved for station 260, 19980504 to 19980613.
# Filtered data saved for station 260, 19981125 to 19990104.
# Processing station ID: 261
# Filtered data saved for station 261, 19980101 to 19980210.
# Filtered data saved for station 261, 19980504 to 19980613.
# Filtered data saved for station 261, 19980614 to 19980724.
# Filtered data saved for station 261, 19980904 to 19981014.
# Filtered data saved for station 261, 19981125 to 19990104.
# Processing station ID: 262
# Filtered data saved for station 262, 19980211 to 19980323.
# Filtered data saved for station 262, 19980504 to 19980613.
# Filtered data saved for station 262, 19980614 to 19980724.
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Filtered data saved for station 271, 19980101 to 19980210.
# Filtered data saved for station 271, 19980211 to 19980323.
# Processing station ID: 272
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Processing station ID: 278
# Processing station ID: 279
# Processing station ID: 281
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Processing station ID: 288
# Processing station ID: 289
# Processing station ID: 294
# Processing station ID: 295
# Processing year: 1999
# Processing station ID: 90
# Processing station ID: 93
# Processing station ID: 95
# Processing station ID: 98
# Filtered data saved for station 98, 19990211 to 19990323.
# Filtered data saved for station 98, 19990725 to 19990903.
# Processing station ID: 99
# Processing station ID: 100
# Filtered data saved for station 100, 19990101 to 19990210.
# Filtered data saved for station 100, 19990211 to 19990323.
# Filtered data saved for station 100, 19990324 to 19990503.
# Filtered data saved for station 100, 19990504 to 19990613.
# Processing station ID: 101
# Filtered data saved for station 101, 19990101 to 19990210.
# Filtered data saved for station 101, 19990211 to 19990323.
# Filtered data saved for station 101, 19990504 to 19990613.
# Filtered data saved for station 101, 19991125 to 20000104.
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Filtered data saved for station 105, 19990101 to 19990210.
# Filtered data saved for station 105, 19990324 to 19990503.
# Filtered data saved for station 105, 19990504 to 19990613.
# Filtered data saved for station 105, 19990614 to 19990724.
# Processing station ID: 106
# Processing station ID: 108
# Processing station ID: 112
# Processing station ID: 114
# Filtered data saved for station 114, 19990504 to 19990613.
# Processing station ID: 115
# Processing station ID: 119
# Processing station ID: 121
# Processing station ID: 127
# Processing station ID: 129
# Processing station ID: 130
# Processing station ID: 131
# Processing station ID: 133
# Processing station ID: 135
# Processing station ID: 136
# Filtered data saved for station 136, 19990725 to 19990903.
# Filtered data saved for station 136, 19990904 to 19991014.
# Processing station ID: 137
# Processing station ID: 138
# Filtered data saved for station 138, 19990614 to 19990724.
# Filtered data saved for station 138, 19990904 to 19991014.
# Filtered data saved for station 138, 19991015 to 19991124.
# Filtered data saved for station 138, 19991125 to 20000104.
# Processing station ID: 140
# Filtered data saved for station 140, 19990101 to 19990210.
# Filtered data saved for station 140, 19990211 to 19990323.
# Filtered data saved for station 140, 19990504 to 19990613.
# Processing station ID: 143
# Filtered data saved for station 143, 19990101 to 19990210.
# Filtered data saved for station 143, 19990504 to 19990613.
# Filtered data saved for station 143, 19990614 to 19990724.
# Filtered data saved for station 143, 19991015 to 19991124.
# Filtered data saved for station 143, 19991125 to 20000104.
# Processing station ID: 146
# Filtered data saved for station 146, 19990324 to 19990503.
# Filtered data saved for station 146, 19990614 to 19990724.
# Processing station ID: 152
# Processing station ID: 155
# Processing station ID: 156
# Processing station ID: 159
# Processing station ID: 162
# Processing station ID: 165
# Processing station ID: 168
# Filtered data saved for station 168, 19990904 to 19991014.
# Processing station ID: 169
# Processing station ID: 170
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Processing station ID: 185
# Processing station ID: 188
# Processing station ID: 189
# Processing station ID: 192
# Filtered data saved for station 192, 19990904 to 19991014.
# Filtered data saved for station 192, 19991125 to 20000104.
# Processing station ID: 201
# Filtered data saved for station 201, 19990211 to 19990323.
# Filtered data saved for station 201, 19990324 to 19990503.
# Filtered data saved for station 201, 19990614 to 19990724.
# Filtered data saved for station 201, 19990725 to 19990903.
# Filtered data saved for station 201, 19990904 to 19991014.
# Request failed: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10). Retrying...
# Filtered data saved for station 201, 19991015 to 19991124.
# Processing station ID: 202
# Filtered data saved for station 202, 19990101 to 19990210.
# Filtered data saved for station 202, 19990504 to 19990613.
# Filtered data saved for station 202, 19990725 to 19990903.
# Filtered data saved for station 202, 19991015 to 19991124.
# Processing station ID: 203
# Filtered data saved for station 203, 19990101 to 19990210.
# Processing station ID: 211
# Processing station ID: 212
# Processing station ID: 216
# Processing station ID: 217
# Processing station ID: 221
# Processing station ID: 226
# Processing station ID: 232
# Processing station ID: 235
# Processing station ID: 236
# Processing station ID: 238
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Processing station ID: 245
# Processing station ID: 247
# Processing station ID: 248
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Filtered data saved for station 260, 19990101 to 19990210.
# Filtered data saved for station 260, 19990504 to 19990613.
# Filtered data saved for station 260, 19990904 to 19991014.
# Filtered data saved for station 260, 19991015 to 19991124.
# Filtered data saved for station 260, 19991125 to 20000104.
# Processing station ID: 261
# Filtered data saved for station 261, 19990101 to 19990210.
# Filtered data saved for station 261, 19990324 to 19990503.
# Filtered data saved for station 261, 19990504 to 19990613.
# Filtered data saved for station 261, 19990904 to 19991014.
# Filtered data saved for station 261, 19991015 to 19991124.
# Processing station ID: 262
# Filtered data saved for station 262, 19990324 to 19990503.
# Filtered data saved for station 262, 19990504 to 19990613.
# Filtered data saved for station 262, 19990904 to 19991014.
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Processing station ID: 272
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Processing station ID: 278
# Processing station ID: 279
# Processing station ID: 281
# Processing station ID: 283
# Processing station ID: 284
# Processing station ID: 285
# Processing station ID: 288
# Processing station ID: 289
# Processing station ID: 294
# Processing station ID: 295
# Filtered data saved for station 295, 19990614 to 19990724.
# Filtered data saved for station 295, 19991125 to 20000104.
# Processing year: 2000
# Processing station ID: 90
# Filtered data saved for station 90, 20000211 to 20000322.
# Filtered data saved for station 90, 20001014 to 20001123.
# Processing station ID: 93
# Processing station ID: 95
# Filtered data saved for station 95, 20000211 to 20000322.
# Filtered data saved for station 95, 20000903 to 20001013.
# Filtered data saved for station 95, 20001124 to 20010103.
# Processing station ID: 98
# Filtered data saved for station 98, 20000323 to 20000502.
# Filtered data saved for station 98, 20000503 to 20000612.
# Filtered data saved for station 98, 20000724 to 20000902.
# Filtered data saved for station 98, 20000903 to 20001013.
# Filtered data saved for station 98, 20001014 to 20001123.
# Filtered data saved for station 98, 20001124 to 20010103.
# Processing station ID: 99
# Processing station ID: 100
# Filtered data saved for station 100, 20000724 to 20000902.
# Filtered data saved for station 100, 20001014 to 20001123.
# Processing station ID: 101
# Processing station ID: 102
# Processing station ID: 104
# Processing station ID: 105
# Processing station ID: 106
# Processing station ID: 108
# Processing station ID: 112
# Processing station ID: 114
# Processing station ID: 115
# Processing station ID: 119
# Processing station ID: 121
# Processing station ID: 127
# Processing station ID: 129
# Processing station ID: 130
# Processing station ID: 131
# Filtered data saved for station 131, 20000211 to 20000322.
# Processing station ID: 133
# Processing station ID: 135
# Filtered data saved for station 135, 20000903 to 20001013.
# Filtered data saved for station 135, 20001124 to 20010103.
# Processing station ID: 136
# Filtered data saved for station 136, 20000101 to 20000210.
# Filtered data saved for station 136, 20000323 to 20000502.
# Filtered data saved for station 136, 20000503 to 20000612.
# Filtered data saved for station 136, 20000724 to 20000902.
# Processing station ID: 137
# Processing station ID: 138
# Filtered data saved for station 138, 20000211 to 20000322.
# Filtered data saved for station 138, 20000323 to 20000502.
# Filtered data saved for station 138, 20000503 to 20000612.
# Filtered data saved for station 138, 20000613 to 20000723.
# Filtered data saved for station 138, 20001014 to 20001123.
# Processing station ID: 140
# Filtered data saved for station 140, 20000211 to 20000322.
# Filtered data saved for station 140, 20000323 to 20000502.
# Filtered data saved for station 140, 20000724 to 20000902.
# Filtered data saved for station 140, 20000903 to 20001013.
# Filtered data saved for station 140, 20001014 to 20001123.
# Filtered data saved for station 140, 20001124 to 20010103.
# Processing station ID: 143
# Filtered data saved for station 143, 20000101 to 20000210.
# Filtered data saved for station 143, 20000323 to 20000502.
# Filtered data saved for station 143, 20000503 to 20000612.
# Filtered data saved for station 143, 20000903 to 20001013.
# Processing station ID: 146
# Processing station ID: 152
# Processing station ID: 155
# Processing station ID: 156
# Processing station ID: 159
# Processing station ID: 162
# Processing station ID: 165
# Processing station ID: 168
# Processing station ID: 169
# Processing station ID: 170
# Processing station ID: 172
# Processing station ID: 174
# Processing station ID: 177
# Processing station ID: 184
# Processing station ID: 185
# Processing station ID: 188
# Processing station ID: 189
# Processing station ID: 192
# Processing station ID: 201
# Processing station ID: 202
# Filtered data saved for station 202, 20000101 to 20000210.
# Filtered data saved for station 202, 20000323 to 20000502.
# Filtered data saved for station 202, 20000613 to 20000723.
# Filtered data saved for station 202, 20000903 to 20001013.
# Processing station ID: 203
# Processing station ID: 211
# Filtered data saved for station 211, 20000503 to 20000612.
# Filtered data saved for station 211, 20000724 to 20000902.
# Filtered data saved for station 211, 20001124 to 20010103.
# Processing station ID: 212
# Filtered data saved for station 212, 20000101 to 20000210.
# Filtered data saved for station 212, 20000211 to 20000322.
# Filtered data saved for station 212, 20000503 to 20000612.
# Filtered data saved for station 212, 20000724 to 20000902.
# Filtered data saved for station 212, 20000903 to 20001013.
# Filtered data saved for station 212, 20001014 to 20001123.
# Filtered data saved for station 212, 20001124 to 20010103.
# Processing station ID: 216
# Filtered data saved for station 216, 20000323 to 20000502.
# Filtered data saved for station 216, 20000503 to 20000612.
# Filtered data saved for station 216, 20000613 to 20000723.
# Filtered data saved for station 216, 20000724 to 20000902.
# Processing station ID: 217
# Processing station ID: 221
# Filtered data saved for station 221, 20000323 to 20000502.
# Processing station ID: 226
# Processing station ID: 232
# Processing station ID: 235
# Processing station ID: 236
# Filtered data saved for station 236, 20000724 to 20000902.
# Processing station ID: 238
# Processing station ID: 239
# Processing station ID: 243
# Processing station ID: 244
# Filtered data saved for station 244, 20001014 to 20001123.
# Processing station ID: 245
# Processing station ID: 247
# Filtered data saved for station 247, 20000503 to 20000612.
# Filtered data saved for station 247, 20000613 to 20000723.
# Filtered data saved for station 247, 20000724 to 20000902.
# Filtered data saved for station 247, 20000903 to 20001013.
# Filtered data saved for station 247, 20001014 to 20001123.
# Filtered data saved for station 247, 20001124 to 20010103.
# Processing station ID: 248
# Filtered data saved for station 248, 20000101 to 20000210.
# Filtered data saved for station 248, 20000323 to 20000502.
# Filtered data saved for station 248, 20000613 to 20000723.
# Filtered data saved for station 248, 20000724 to 20000902.
# Filtered data saved for station 248, 20000903 to 20001013.
# Filtered data saved for station 248, 20001124 to 20010103.
# Processing station ID: 251
# Processing station ID: 252
# Processing station ID: 253
# Processing station ID: 254
# Processing station ID: 255
# Processing station ID: 257
# Processing station ID: 258
# Processing station ID: 259
# Processing station ID: 260
# Processing station ID: 261
# Processing station ID: 262
# Processing station ID: 263
# Processing station ID: 264
# Processing station ID: 266
# Processing station ID: 268
# Processing station ID: 271
# Processing station ID: 272
# Processing station ID: 273
# Processing station ID: 276
# Processing station ID: 277
# Filtered data saved for station 277, 20000724 to 20000902.
# Processing station ID: 278
# Filtered data saved for station 278, 20000101 to 20000210.
# Filtered data saved for station 278, 20000211 to 20000322.
# Filtered data saved for station 278, 20000503 to 20000612.
# Filtered data saved for station 278, 20001014 to 20001123.
# Filtered data saved for station 278, 20001124 to 20010103.
# Processing station ID: 279
# Filtered data saved for station 279, 20000211 to 20000322.
# Filtered data saved for station 279, 20000613 to 20000723.
# Filtered data saved for station 279, 20000903 to 20001013.
# Filtered data saved for station 279, 20001124 to 20010103.
# Processing station ID: 281
# Filtered data saved for station 281, 20000503 to 20000612.
# Filtered data saved for station 281, 20000724 to 20000902.
# Filtered data saved for station 281, 20000903 to 20001013.
# Filtered data saved for station 281, 20001124 to 20010103.
# Processing station ID: 283
# Processing station ID: 284
# Filtered data saved for station 284, 20000101 to 20000210.
# Filtered data saved for station 284, 20000724 to 20000902.
# Filtered data saved for station 284, 20000903 to 20001013.
# Processing station ID: 285
# Processing station ID: 288
# Filtered data saved for station 288, 20000503 to 20000612.
# Processing station ID: 289
# Processing station ID: 294
# Processing station ID: 295
# Filtered data saved for station 295, 20000211 to 20000322.
# Filtered data saved for station 295, 20000613 to 20000723.
# Filtered data saved for station 295, 20000903 to 20001013.
# Filtered data saved for station 295, 20001014 to 20001123.
# Filtered data saved for station 295, 20001124 to 20010103.

# %%
import os
import json
from datetime import datetime
import pandas as pd

#CSV 파일 경로
csv_file_path = "../data/meteorological/location.csv"

#JSON 파일들이 저장된 디렉토리
save_dir = "../base/data"

#CSV 데이터 로드 및 전처리
csv_data = pd.read_csv(csv_file_path)
csv_data['시작시각'] = pd.to_datetime(csv_data['시작시각'], format='%Y.%m.%d %H:%M:%S')
station_start_times = dict(zip(csv_data['지점번호'].astype(str), csv_data['시작시각']))

#디렉토리 내 파일 확인
files = os.listdir(save_dir)

#삭제 대상 파일 확인 및 삭제
for file_name in files:
    if file_name.endswith(".json"):
        try:
            # 파일명에서 station과 날짜 추출
            parts = filename.split('')
            stationid = parts[1]  # 'station'에서 '' 추출
            file_date = datetime.strptime(parts[2], "%Y%m%d")  # '19700101' -> 날짜 변환

            # 지점번호와 시작시각 매칭 확인
            if station_id in station_start_times:
                start_time = station_start_times[station_id]
                if file_date < start_time:
                    continue  # 시작시간보다 이전 날짜 파일은 유지

            # JSON 파일 열어서 'resultCode' 확인
            file_path = os.path.join(save_dir, file_name)
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)

            if (
                "response" in data and
                "header" in data["response"] and
                data["response"]["header"].get("resultCode") == "03"
            ):
                os.remove(file_path)  # 파일 삭제
                print(f"Deleted file: {file_name}")

        except Exception as e:
            print(f"Error processing file {file_name}: {e}")

# %%
from dash import Dash, html, dcc, Input, Output, State
import dash_bootstrap_components as dbc

# 스타일 설정
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "250px",
    "padding": "20px",
    "background-color": "#f8f9fa",
    "transition": "0.3s",
    "overflow-x": "hidden"
}

SIDEBAR_HIDDEN = {
    **SIDEBAR_STYLE,
    "margin-left": "-250px"
}

CONTENT_STYLE = {
    "margin-left": "250px",
    "padding": "20px",
    "transition": "0.3s"
}

CONTENT_EXPANDED = {
    **CONTENT_STYLE,
    "margin-left": "0"
}

# Dash 애플리케이션 생성
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# 사이드바 레이아웃
sidebar = html.Div(
    [
        html.H2("Menu", className="display-4"),
        html.Hr(),
        html.P("Select a page:", className="lead"),
        dbc.Nav(
            [
                dbc.NavLink("Home", href="/", id="home-link"),
                dbc.NavLink("Tab 1", href="/tab1", id="tab1-link"),
                dbc.NavLink("Tab 2", href="/tab2", id="tab2-link"),
                dbc.NavLink("Tab 3", href="/tab3", id="tab3-link"),
                dbc.NavLink("Tab 4", href="/tab4", id="tab4-link"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
    id="sidebar",
)

# 메인 콘텐츠 레이아웃
content = html.Div(id="page-content", style=CONTENT_STYLE)

# 전체 레이아웃
app.layout = html.Div([
    dcc.Location(id="url"),  # URL 변경 감지
    sidebar,
    dbc.Button(
        "Toggle Sidebar", id="sidebar-toggle", color="primary", n_clicks=0, style={"margin": "10px"}
    ),
    content,
])

# 콜백 설정
@app.callback(
    [Output("sidebar", "style"), Output("page-content", "style")],
    [Input("sidebar-toggle", "n_clicks")],
    [State("sidebar", "style"), State("page-content", "style")],
)
def toggle_sidebar(n, sidebar_style, content_style):
    """사이드바 열고 닫기"""
    if n % 2 == 1:  # 홀수 클릭: 닫기
        return SIDEBAR_HIDDEN, CONTENT_EXPANDED
    else:           # 짝수 클릭: 열기
        return SIDEBAR_STYLE, CONTENT_STYLE

@app.callback(
    Output("page-content", "children"),
    [Input("url", "pathname")],
)
def render_page(pathname):
    """URL에 따라 페이지 콘텐츠 변경"""
    if pathname == "/tab1":
        return html.Div([
            html.H1("Tab 1"),
            html.P("Content for Tab 1"),
        ])
    elif pathname == "/tab2":
        return html.Div([
            html.H1("Tab 2"),
            html.P("Content for Tab 2"),
        ])
    elif pathname == "/tab3":
        return html.Div([
            html.H1("Tab 3"),
            html.P("Content for Tab 3"),
        ])
    elif pathname == "/tab4":
        return html.Div([
            html.H1("Tab 4"),
            html.P("Content for Tab 4"),
        ])
    else:  # 기본 페이지 (Home)
        return html.Div([
            html.H1("Home"),
            html.P("This is the Home Page. Project overview and details will go here."),
        ])

# 애플리케이션 실행
if __name__ == "__main__":
    app.run_server(debug=True)
